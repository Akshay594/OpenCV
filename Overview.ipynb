# %% [markdown]
# # 1. Basics of Computer Vision
#
# <ol>
# <li>Reading Writing and Displaying images</li>
# <li>Grayscaling</li>
# <li>Colors HSV Hue Saturation Value</li>
# <li>Colors Gray RGB</li>
# <li>Colors Red Green Blue</li>
# <li>Histograms</li>
# <li>Drawing Images</li>
# </ol>
#
# # 2. Image Manipulations
#
# <ol>
# <li>Transformation</li>
# <li>Translations</li>
# <li>Rotations</li>
# <li>Scaling Resizing and interpolation</li>
# <li>Image Pyramids</li>
# <li>Cropping</li>
# <li>Airthmetic Operations</li>
# <li>Bitwise operations and masking</li>
# <li>Convolution and Blurring</li>
# <li>Sharpening</li>
# <li>Thresholding binarization</li>
# <li>Dilation Erosion Opening and Closing</li>
# <li>Edge Detection and Image Gradients</li>
# <li>Perspective and affine transform</li>
# <li>Live sketching</li>
# </ol>
#
#
# # 3. Image Segmentation
#
# <ol>
# <li>Understanding Contours</li>
# <li>Sorting Contours</li>
# <li>Approximating Contours and Convex Hull</li>
# <li>Matching Contours Shape</li>
# <li>Identifying contours by shape</li>
# <li>Line Detection using Hough Line</li>
# <li>Circle Detection Using Hough Circles</li>
# <li>Blob Detection</li>
# <li>Counting circle and ellipses</li>
# </ol>
#
# # 4. Object Detection
#
# <ol>
# <li>Feature Description Theory</li>
# <li>Finding Waldo</li>
# <li>Finding Corners</li>
# <li>Histogram of Oriented Gradients</li>
# <li>HAAR Cascade</li>
# <li>Face and Eye Detection</li>
# <li>Car Detection</li>
# <li>Pedestrian Detection</li>
# </ol>
#
# # 5. Augmented Reality
# <ol>
# <li>Facial Landmarks</li>
# <li>Yawn Detector and Counting</li>
# <li>Augmented Machine Learning</li>
# </ol>
#
# # 6. Simple Machine Learning
# <ol>
# <li>Digit Classifier</li>
# <li>Credit Card Reader</li>
# <li>Face Recognition and unlock your computer with your face</li>
# </ol>
#
# # 7. Object Tracking
# <ol>
# <li>Filtering by color</li>
# <li>Background Subtraction</li>
# <li>Meanshift Object Tracking</li>
# <li>Camshift Object Tracking</li>
# <li>Optical Flow</li>
# <li>Ball Tracking</li>
# </ol>
#
# # 8. Computer Photography
# <ol>
# <li>Photo Denoising</li>
# <li>Photo restoration using inpainting</li>
# <li>Automatic Number plate recognition</li>
# </ol>
#
# # 9. Self Driving Cars (Project)
#
# # 10. Deep Learning
# <ol>
# <li>Neural Style Transfer</li>
# <li>Mask RCNN</li>
# </ol>
